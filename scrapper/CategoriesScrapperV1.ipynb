# %% [markdown]
# Scrap websites mentioned in file to collect food categories. It scrapps all pages and after that saves it all to a file.

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
from bs4 import Comment

# %% [markdown]
# ## Read file

# %% [markdown]
# You have to specified number of rows to read from a file - check first how many rows are there in the scv file.
# Without 'nrows' parameter an exception occures.

# %%
df = pd.read_csv('food_data_excerpt/food_data_excerpt.csv', sep=',', encoding='utf8', nrows=336936)#, engine='python'

# %%
df.head()
# Out:
#   country  country_region    zip       city                 date  \
# 0      DE               7  47169   Duisburg  2013-02-28 23:59:59
# 1      DE               9  66564  Ottweiler  2013-03-01 00:00:01
# 2      DE               7     -1  Hattingen  2013-03-01 00:00:02
# 3      DE               5     -1   Sulzbach  2013-03-01 00:00:04
# 4      DE              11     -1      Calau  2013-03-01 00:00:06
#
#                                          target_link  \
# 0  /rezept/443097/Abendbrot-UEberbackenes-Broetch...
# 1                     /rezept/108268/Coq-au-vin.html
# 2  /rezept/231469/Kuchen-Blechkuchen-Kaesekuchen-...
# 3           /rezept/410839/Bier-Wackler-Dessert.html
# 4           /rezept/392545/Black-Bottom-Cupcake.html
#
#                                          origin_link  \
# 0  http://www.kochbar.de/kochen/Auflaeufe-zuberei...
# 1      http://www.kochbar.de/rezepte/coq-au-vin.html
# 2                                                  -
# 3  http://www.google.de/url?sa=t&rct=j&q=wackler%...
# 4  http://www.kochbar.de/rezepte/cupcakes.html?of...
#
#                                            host_type  recipe_id
# 0  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:2.0.1) ...     443097
# 1  Mozilla/5.0 (Windows NT 5.1; rv:19.0) Gecko/20...     108268
# 2  Mozilla/5.0 (iPad; CPU OS 6_0_1 like Mac OS X)...     231469
# 3  Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKi...     410839
# 4  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:19.0) G...     392545

# %% [markdown]
# ## Collect data

# %%
def find_comment(soup, wanted_comment='REZEPT-KATEGORIEN'):
    found = False

    comments = soup.find_all(string=lambda text:isinstance(text, Comment))
    i = 0
    while not found and i < len(comments):
        node = comments[i]
        if node.strip() == wanted_comment:
            #print('comment found')
            found = True

        i+=1
    return node

# %%
def find_categories(soup, wanted_class = 'rtli-pb-small'):
    data = []
    node = find_comment(soup)
    startOfItems, endOfItems = False, False
    
    while not endOfItems and node.find_next_sibling():
        node = node.find_next_sibling()

        if node['class'][0] == wanted_class:
            startOfItems = True

            if node.findChild().name == 'a':
                data.append(node.a.text)
            elif node.findChild().name == 'span':
                data.append(node.span.text)

        elif startOfItems:
            endOfItems = True
    
    return data

# %%
domain = 'http://www.kochbar.de'

# %% [markdown]
# Remember to specify with rows to process. If 'all_rows' is set to True, 'start_index' and 'end_index' is not taken into account.

# %%
start_index, end_index = 40, 50
all_rows = True

# %%
import time
start = time.time()

data = []

if not all_rows:
    df = df[start_index:end_index]

for url in df['target_link']:
    #print(domain + url)
    
    response = requests.get(domain + url)
    
    if response.url != 'https://www.kochbar.de/rezepte/' and response.status_code == 200:
        #print('Request status ok!')
        soup = BeautifulSoup(response.content.decode('utf-8','ignore'), "lxml")
        categories = find_categories(soup)
        #print('categories:', categories, '\n')
        data.append(categories)
    elif response.status_code == 200:
        #print('This webpage is probably no longer available!')
        data.append(None)
    else:
        #print('Not correct request status: ', response.status_code)
        data.append(None)
        
print(time.time() - start)

# %% [markdown]
# ## Extend dataframe

# %%
df['categories'] = data
df.head()
# Out:
#    country  country_region    zip         city                 date  \
# 40      DE              13   4651  Bad_Lausick  2013-03-01 00:00:58
# 41      DE               9  66564    Ottweiler  2013-03-01 00:01:00
# 42      DE              11     -1  Brandenburg  2013-03-01 00:01:01
# 43      DE               6     -1      Hanover  2013-03-01 00:01:01
# 44      DE               5     -1       Kassel  2013-03-01 00:01:01
#
#                                           target_link  \
# 40          /rezept/363977/Entenbraten-klassisch.html
# 41                     /rezept/413547/Coq-au-Vin.html
# 42  /rezept/397242/Spanferkelbraten-NT-mit-frische...
# 43                  /rezept/450876/Gemuesenudeln.html
# 44         /rezept/38466/Schneller-Himbeerkuchen.html
#
#                                           origin_link  \
# 40  http://www.google.de/url?sa=t&rct=j&q=&esrc=s&...
# 41      http://www.kochbar.de/rezepte/coq-au-vin.html
# 42                                                  -
# 43  http://www.kochbar.de/rezepte/alle-rezepte.htm...
# 44  http://www.kochbar.de/rezepte/himbeertorte.htm...
#
#                                             host_type  recipe_id  \
# 40  Mozilla/5.0 (Windows NT 5.1; rv:19.0) Gecko/20...     363977
# 41  Mozilla/5.0 (Windows NT 5.1; rv:19.0) Gecko/20...     413547
# 42  Mozilla/5.0 (compatible; MSIE 9.0; Windows NT ...     397242
# 43  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:19.0) G...     450876
# 44  Mozilla/5.0 (iPad; CPU OS 6_0_1 like Mac OS X)...      38466
#
#                                            categories
# 40  [Fleisch, Sächsische Küche, Mittagstisch, Haup...
# 41  [Europa, Frankreich, mit Alkohol, Fleisch, Mil...
# 42  [Beilagen, mit Alkohol, Fleisch, Hauptspeise, ...
# 43  [Hauptspeise, schnell & einfach, Fleisch, lakt...
# 44                        [Kuchen/Torte, ohne Weizen]

# %%
df = df[['country', 'country_region', 'city', 'date', 'recipe_id', 'categories']]
df.head()
# Out:
#    country  country_region         city                 date  recipe_id  \
# 40      DE              13  Bad_Lausick  2013-03-01 00:00:58     363977
# 41      DE               9    Ottweiler  2013-03-01 00:01:00     413547
# 42      DE              11  Brandenburg  2013-03-01 00:01:01     397242
# 43      DE               6      Hanover  2013-03-01 00:01:01     450876
# 44      DE               5       Kassel  2013-03-01 00:01:01      38466
#
#                                            categories
# 40  [Fleisch, Sächsische Küche, Mittagstisch, Haup...
# 41  [Europa, Frankreich, mit Alkohol, Fleisch, Mil...
# 42  [Beilagen, mit Alkohol, Fleisch, Hauptspeise, ...
# 43  [Hauptspeise, schnell & einfach, Fleisch, lakt...
# 44                        [Kuchen/Torte, ohne Weizen]

# %% [markdown]
# ## Save data to file

# %%
df.to_csv('files/categories.csv', index=None, header=True, encoding='utf8')

# %% [markdown]
# ## Check correctness of the file

# %%
pd.read_csv('files/categories.csv')
# Out:
#   country  country_region         city                 date  recipe_id  \
# 0      DE              13  Bad_Lausick  2013-03-01 00:00:58     363977
# 1      DE               9    Ottweiler  2013-03-01 00:01:00     413547
# 2      DE              11  Brandenburg  2013-03-01 00:01:01     397242
# 3      DE               6      Hanover  2013-03-01 00:01:01     450876
# 4      DE               5       Kassel  2013-03-01 00:01:01      38466
# 5      DE               7        Essen  2013-03-01 00:01:02     317291
# 6      DE               8      Koblenz  2013-03-01 00:01:02     458991
# 7      DE               2       Neusäß  2013-03-01 00:01:04     269164
# 8      DE              16       Berlin  2013-03-01 00:01:09     209594
# 9      CH               5         Bern  2013-03-01 00:01:10     421887
#
#                                           categories
# 0  ['Fleisch', 'Sächsische Küche', 'Mittagstisch'...
# 1  ['Europa', 'Frankreich', 'mit Alkohol', 'Fleis...
# 2  ['Beilagen', 'mit Alkohol', 'Fleisch', 'Haupts...
# 3  ['Hauptspeise', 'schnell & einfach', 'Fleisch'...
# 4                    ['Kuchen/Torte', 'ohne Weizen']
# 5                                                NaN
# 6  ['Konfekt/Süßware', 'Kuchen/Torte', 'Plätzchen...
# 7  ['Fisch', 'Hauptspeise', 'Gesund und Diät', 'o...
# 8  ['Europa', 'Auflauf /Überbackenes', 'Fleisch',...
# 9  ['Salate', 'Fleisch', 'Mittagstisch', 'Abendes...
